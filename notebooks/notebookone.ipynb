// %%
import { agent } from "../agents/main.ts";

// Obtener el grafo en formato Mermaid
const graph = await agent.getGraphAsync() as any;
const mermaidString = graph.drawMermaid();

console.log(mermaidString);
// Out:
// Stack trace:
// TypeError: Module not found "file:///C:/Users/aavel/Documents/Dev/9.%20Java/2026/agent-ia/src/agents/main.ts".
//     at async <anonymous>:1:40
